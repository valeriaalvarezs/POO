# %%
import pandas as pd

# %%
import numpy as np
precios=np.random.rand(10)
closed=np.random.randint(1,100,10)

# %%
closed
# Out:
# array([60, 29, 18, 82,  6, 32, 55, 39, 59, 58])

# %%
diccionario={"Precios":precios,
             "Cierre":closed}

precio=pd.DataFrame(diccionario)

precio
# Out:
#     Precios  Cierre
# 0  0.963244      60
# 1  0.452867      29
# 2  0.615697      18
# 3  0.514203      82
# 4  0.220152       6
# 5  0.778582      32
# 6  0.017630      55
# 7  0.828735      39
# 8  0.322469      59
# 9  0.731913      58

# %%
precio['Cierre']>20
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: Cierre, dtype: bool

# %%
precio[precio['Cierre']>20]
# Out:
#     Precios  Cierre
# 0  0.963244      60
# 1  0.452867      29
# 3  0.514203      82
# 5  0.778582      32
# 6  0.017630      55
# 7  0.828735      39
# 8  0.322469      59
# 9  0.731913      58
